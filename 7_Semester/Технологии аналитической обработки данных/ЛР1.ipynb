# %%
import numpy as np
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier
# Out:
# /usr/lib/python3/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.17.3 and <1.25.0 is required for this version of SciPy (detected version 1.25.2
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# #1 Задание

# %%
df = pd.DataFrame(pd.read_csv("./titanic.csv"))
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# #2 Задание

# %%
df = df.drop(columns=['PassengerId', 'Name', 'SibSp', 'Parch', 'Ticket', 'Cabin', 'Embarked'], axis=1)
df
# Out:
#      Survived  Pclass     Sex   Age     Fare
# 0           0       3    male  22.0   7.2500
# 1           1       1  female  38.0  71.2833
# 2           1       3  female  26.0   7.9250
# 3           1       1  female  35.0  53.1000
# 4           0       3    male  35.0   8.0500
# ..        ...     ...     ...   ...      ...
# 886         0       2    male  27.0  13.0000
# 887         1       1  female  19.0  30.0000
# 888         0       3  female   NaN  23.4500
# 889         1       1    male  26.0  30.0000
# 890         0       3    male  32.0   7.7500
#
# [891 rows x 5 columns]

# %% [markdown]
# #3 Задание
# Sex

# %%
df['Sex'] = df.apply(lambda row: row['Sex'] == "male", axis=1)
df
# Out:
#      Survived  Pclass    Sex   Age     Fare
# 0           0       3   True  22.0   7.2500
# 1           1       1  False  38.0  71.2833
# 2           1       3  False  26.0   7.9250
# 3           1       1  False  35.0  53.1000
# 4           0       3   True  35.0   8.0500
# ..        ...     ...    ...   ...      ...
# 886         0       2   True  27.0  13.0000
# 887         1       1  False  19.0  30.0000
# 888         0       3  False   NaN  23.4500
# 889         1       1   True  26.0  30.0000
# 890         0       3   True  32.0   7.7500
#
# [891 rows x 5 columns]

# %% [markdown]
# #4 Задание

# %%
df['Survived']
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %% [markdown]
# #5 Задание

# %%
df = df.dropna()
df
# Out:
#      Survived  Pclass    Sex   Age     Fare
# 0           0       3   True  22.0   7.2500
# 1           1       1  False  38.0  71.2833
# 2           1       3  False  26.0   7.9250
# 3           1       1  False  35.0  53.1000
# 4           0       3   True  35.0   8.0500
# ..        ...     ...    ...   ...      ...
# 885         0       3  False  39.0  29.1250
# 886         0       2   True  27.0  13.0000
# 887         1       1  False  19.0  30.0000
# 889         1       1   True  26.0  30.0000
# 890         0       3   True  32.0   7.7500
#
# [714 rows x 5 columns]

# %% [markdown]
# #6 Задание

# %%
X = df.drop(columns=['Survived'], axis=1)
y = df['Survived']
clf = DecisionTreeClassifier(random_state=241)
decision_tree = clf.fit(X, y)

# %% [markdown]
# #7 Задание

# %%
decision_tree.feature_importances_
# Out:
# array([0.14000522, 0.30051221, 0.2560461 , 0.30343647])

# %%
decision_tree.feature_names_in_
# Out:
# array(['Pclass', 'Sex', 'Age', 'Fare'], dtype=object)

# %%
X
# Out:
#      Pclass    Sex   Age     Fare
# 0         3   True  22.0   7.2500
# 1         1  False  38.0  71.2833
# 2         3  False  26.0   7.9250
# 3         1  False  35.0  53.1000
# 4         3   True  35.0   8.0500
# ..      ...    ...   ...      ...
# 885       3  False  39.0  29.1250
# 886       2   True  27.0  13.0000
# 887       1  False  19.0  30.0000
# 889       1   True  26.0  30.0000
# 890       3   True  32.0   7.7500
#
# [714 rows x 4 columns]

# %% [markdown]
# #Ответ Sex и Fare
